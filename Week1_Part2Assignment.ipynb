# %%
import matplotlib.pyplot as plt
import networkx as nx

# %matplotlib inline
BH=nx.Graph()
BH.add_edge('andre','beverly')
BH.add_edge('andre','carol')
BH.add_edge('andre','diane')
BH.add_edge('beverly','andre')
BH.add_edge('beverly','diane')
BH.add_edge('beverly','ed')
BH.add_edge('carol','andre')
BH.add_edge('carol','diane')
BH.add_edge('carol','fernando')
BH.add_edge('fernando','garth')
BH.add_edge('fernando','diane')
BH.add_edge('fernando','carol')
BH.add_edge('garth','ed')
BH.add_edge('garth','diane')
BH.add_edge('garth','fernando')
BH.add_edge('garth','heather')
BH.add_edge('ed','beverly')
BH.add_edge('ed','diane')
BH.add_edge('ed','garth')
BH.add_edge('heather','fernando')
BH.add_edge('heather','garth')
BH.add_edge('heather','ike')
BH.add_edge('ike','heather')
BH.add_edge('ike','jane')
BH.add_edge('jane','ike')

P={'andre':(0,3),'beverly':(0,1),'carol':(1,4),'diane':(1,2),'ed':(1,0),'ike':(4,2),'garth':(2,1),'jane':(5,2),'fernando':(2,3),'heather':(3,2)}
nx.draw_networkx_nodes(BH,P,node_size=1000,node_color='yellow')
nx.draw_networkx_edges(G,P)
nx.draw_networkx_labels(G,P)
plt.show()
